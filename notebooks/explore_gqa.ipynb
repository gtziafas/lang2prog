# %%
 cd /data/p300488/lang2prog
# Out:
# /data/p300488/lang2prog

# %% [markdown]
# # Exploring GQA questions dataset

# %%
import os
gqa_path = '/data/p300488/datasets/gqa'
train_questions_path = os.path.join(gqa_path, 'questions/train_balanced_questions.json')
train_scenes_path = os.path.join(gqa_path, 'scenes/train_sceneGraphs.json')

# %% [markdown]
# Read GQA questions dataset. Size of training set?

# %%
import json
ds = json.load(open(train_questions_path))
#ds = list(ds.values())
print(len(ds))
# Out:
# 943000

# %% [markdown]
# Let's see the annotation of a training example

# %%
from pprint import pprint

pprint(list(ds.values())[0])
# Out:
# {'annotations': {'answer': {},
#                  'fullAnswer': {'2': '2486325'},
#                  'question': {'2': '2486325'}},
#  'answer': 'yes',
#  'entailed': ['02930160',
#               '02930158',
#               '02930159',
#               '02930154',
#               '02930155',
#               '02930156',
#               '02930153'],
#  'equivalent': ['02930152'],
#  'fullAnswer': 'Yes, the sky is dark.',
#  'groups': {'global': None, 'local': '06-sky_dark'},
#  'imageId': '2354786',
#  'isBalanced': True,
#  'question': 'Is the sky dark?',
#  'semantic': [{'argument': 'sky (2486325)',
#                'dependencies': [],
#                'operation': 'select'},
#               {'argument': 'dark',
#                'dependencies': [0],
#                'operation': 'verify color'}],
#  'semanticStr': 'select: sky (2486325)->verify color: dark [0]',
#  'types': {'detailed': 'verifyAttr',
#            'semantic': 'attr',
#            'structural': 'verify'}}

# %% [markdown]
# Let' s see the structure and type of the questions.

# %%
# what question structures in each question type
q_struc_types = {}
for _, sample in ds.items():
    typ = sample['types']['semantic']
    if typ not in q_struc_types.keys():
        q_struc_types[typ] = set()
    q_struc_types[typ].add(sample['types']['structural'])
                 
pprint(q_struc_types)
# Out:
# {'attr': {'choose', 'query', 'logical', 'compare', 'verify'},
#  'cat': {'query', 'choose'},
#  'global': {'query', 'verify', 'choose'},
#  'obj': {'logical', 'verify'},
#  'rel': {'query', 'verify', 'choose'}}

# %% [markdown]
# Structure means what is the final reasoning step
#
#  - **verify**:
#   yes/no (e.g  Is the bowl red?
#           ==> select: bowl -> verify color: red [0] )
#
#  - **choose**:
#   multiple choice A or B (e.g.  Is it rainy or sunny?
#                           ==> select: it -> choose: rainy|sunny [0])
#
#  - **compare**:
#   compare attributes of two entities (e.g    Are the bowl and the cup the same color?
#                                       ==>    select: bowl -> select: cup -> same color: [0,1])
#
#  - **logical**:
#    two verify branches connected with and/or (e.g.   Is there either a large bowl or a cup?
#                                               ==>    select: bowl -> filter size: large [0] -> exist: ? [1]
#                                                   -> select: cup -> > exist: ? [3] -> or: [2,4]
#
#  - **query**:
#    ask for the name, an attrubute or the position of an entity
#       (e.g.  What is the cup made of?
#        ==>  select: cup -> query: material [0] )

# %% [markdown]
# Question type means what the question is about:
#    - **attr** : about an attribute of an entity (e.g. Is the bowl red?, Is the glass broken?)
#    - **cat**: about the name/category of an entity (e.g.  What soda drink is this?)
#    - **global**: about the weather, the location or the background of the scene
#    - **obj**: about the existence of certain objects  (e.g. Is there a big dog?)
#    - **rel**: contains relationship between two entities  (What is the man sitting in the chair eating?)

# %% [markdown]
# Let's see what are all the different reasoning primitives

# %%
all_primitives = set()
for _, sample in ds.items():
    functions = sample['semantic']
    for fn in functions:
        all_primitives.add(fn['operation'])

pprint(all_primitives)
# Out:
# {'and',
#  'choose',
#  'choose activity',
#  'choose age',
#  'choose brightness',
#  'choose cleanliness',
#  'choose color',
#  'choose company',
#  'choose depth',
#  'choose face expression',
#  'choose fatness',
#  'choose flavor',
#  'choose gender',
#  'choose hardness',
#  'choose healthier',
#  'choose height',
#  'choose hposition',
#  'choose larger',
#  'choose length',
#  'choose less healthy',
#  'choose location',
#  'choose lower',
#  'choose material',
#  'choose name',
#  'choose older',
#  'choose opaqness',
#  'choose pattern',
#  'choose place',
#  'choose pose',
#  'choose race',
#  'choose realism',
#  'choose rel',
#  'choose shape',
#  'choose shorter',
#  'choose size',
#  'choose smaller',
#  'choose sportActivity',
#  'choose state',
#  'choose taller',
#  'choose thickness',
#  'choose tone',
#  'choose vposition',
#  'choose weather',
#  'choose weight',
#  'choose width',
#  'choose younger',
#  'common',
#  'different',
#  'different color',
#  'different shape',
#  'exist',
#  'filter',
#  'filter activity',
#  'filter age',
#  'filter brightness',
#  'filter cleanliness',
#  'filter color',
#  'filter company',
#  'filter depth',
#  'filter event',
#  'filter face expression',
#  'filter fatness',
#  'filter flavor',
#  'filter gender',
#  'filter hardness',
#  'filter height',
#  'filter hposition',
#  'filter length',
#  'filter liquid',
#  'filter material',
#  'filter opaqness',
#  'filter orientation',
#  'filter pattern',
#  'filter pose',
#  'filter race',
#  'filter realism',
#  'filter room',
#  'filter shape',
#  'filter size',
#  'filter sport',
#  'filter sportActivity',
#  'filter state',
#  'filter texture',
#  'filter thickness',
#  'filter tone',
#  'filter vposition',
#  'filter weather',
#  'filter weight',
#  'filter width',
#  'or',
#  'query',
#  'relate',
#  'same',
#  'same color',
#  'same material',
#  'same shape',
#  'select',
#  'verify',
#  'verify activity',
#  'verify age',
#  'verify brightness',
#  'verify cleanliness',
#  'verify color',
#  'verify company',
#  'verify depth',
#  'verify face expression',
#  'verify fatness',
#  'verify flavor',
#  'verify gender',
#  'verify hardness',
#  'verify height',
#  'verify hposition',
#  'verify length',
#  'verify location',
#  'verify material',
#  'verify opaqness',
#  'verify pattern',
#  'verify place',
#  'verify pose',
#  'verify race',
#  'verify realism',
#  'verify rel',
#  'verify room',
#  'verify shape',
#  'verify size',
#  'verify sportActivity',
#  'verify state',
#  'verify texture',
#  'verify thickness',
#  'verify tone',
#  'verify type',
#  'verify vposition',
#  'verify weather',
#  'verify weight',
#  'verify width'}

# %% [markdown]
# These primitives are attribute-aware. Let's see them if we treat attribute as argument:

# %%
all_attributes=set()
primitives=set()
primitives_and_attributes = {}
for fn in all_primitives:
        toks = fn.split(' ')
        primitive = toks[0]
        primitives.add(primitive)

        if primitive not in primitives_and_attributes.keys():
            primitives_and_attributes[primitive] = set()

        if len(toks) > 1:
            all_attributes.add(toks[1])
            primitives_and_attributes[primitive].add(toks[1])

pprint(primitives)
# Out:
# {'and',
#  'choose',
#  'common',
#  'different',
#  'exist',
#  'filter',
#  'or',
#  'query',
#  'relate',
#  'same',
#  'select',
#  'verify'}

# %% [markdown]
# From these ```verify, filter, query, same/different``` and ```choose``` are associated with attribute concepts. Do all attributes appear in all primitives? Let's see them

# %%
for fn, atts in primitives_and_attributes.items():
        if atts:
            print(f"{fn} ({len(atts)})\n{','.join(sorted(atts))}")
            print()
# Out:
# choose (44)
# activity,age,brightness,cleanliness,color,company,depth,face,fatness,flavor,gender,hardness,healthier,height,hposition,larger,length,less,location,lower,material,name,older,opaqness,pattern,place,pose,race,realism,rel,shape,shorter,size,smaller,sportActivity,state,taller,thickness,tone,vposition,weather,weight,width,younger
#
# verify (37)
# activity,age,brightness,cleanliness,color,company,depth,face,fatness,flavor,gender,hardness,height,hposition,length,location,material,opaqness,pattern,place,pose,race,realism,rel,room,shape,size,sportActivity,state,texture,thickness,tone,type,vposition,weather,weight,width
#
# filter (37)
# activity,age,brightness,cleanliness,color,company,depth,event,face,fatness,flavor,gender,hardness,height,hposition,length,liquid,material,opaqness,orientation,pattern,pose,race,realism,room,shape,size,sport,sportActivity,state,texture,thickness,tone,vposition,weather,weight,width
#
# same (3)
# color,material,shape
#
# different (2)
# color,shape

# %% [markdown]
# For some reason only in the ```query``` primitive attribute concepts are defined as arguments. Same for some cases of ```same/different``` primitives. Let's retrieve them and compare with other attributes.

# %%
temp = {f: set() for f in ['query', 'same', 'different']}
for _, sample in ds.items():
    ops = [fn['operation'] for fn in sample['semantic']]
    for fn_name in ['query', 'same', 'different']:
        if fn_name in ops:
            arg = sample['semantic'][ops.index(fn_name)]['argument']
            if arg != 'None':
                temp[fn_name].add(arg)

pprint(temp)
# Out:
# {'different': {'type', 'gender'},
#  'query': {'15',
#            '16',
#            '18',
#            '24',
#            '25',
#            '27',
#            '31',
#            'activity',
#            'age',
#            'cleanliness',
#            'color',
#            'company',
#            'depth',
#            'face expression',
#            'fatness',
#            'flavor',
#            'gender',
#            'hardness',
#            'height',
#            'hposition',
#            'length',
#            'material',
#            'name',
#            'pattern',
#            'place',
#            'pose',
#            'race',
#            'realism',
#            'room',
#            'shape',
#            'size',
#            'sport',
#            'sportActivity',
#            'state',
#            'texture',
#            'thickness',
#            'tone',
#            'weather',
#            'weight',
#            'width'},
#  'same': {'type', 'gender'}}

# %% [markdown]
# wtf are the numbers?

# %%
def print_qa(sample):
    print(f"Q: {sample['question']}")
    print(f"P: {sample['semanticStr']}")
    print(f"A: {sample['answer']}")
    print()

    
for _, sample in ds.items():
    ops = [fn['operation'] for fn in sample['semantic']]
    if 'query' in ops:
        arg = sample['semantic'][ops.index('query')]['argument']
        if arg in ['15', '16', '18', '24', '25', '27', '31']:
            print_qa(sample)
# Out:
# Q: What's the man doing?
# P: select: man (758399)->query: 27 [0]
# A: taking pictures
#
# Q: What is the person doing?
# P: select: person (875671)->query: 15 [0]
# A: taking a picture
#
# Q: What is he doing?
# P: select: he (2580846)->query: 18 [0]
# A: brushing teeth
#
# Q: What's he doing?
# P: select: he (1620687)->query: 31 [0]
# A: brushing teeth
#
# Q: What are the people to the left of the chair doing?
# P: select: chair (653821)->relate: people,to the left of,s (653812) [0]->query: 16 [1]
# A: taking pictures
#
# Q: What is the man to the left of the people doing?
# P: select: people (2424517)->relate: man,to the left of,s (3867654) [0]->query: 24 [1]
# A: making a face
#
# Q: What is the woman doing?
# P: select: woman (317132)->query: 25 [0]
# A: brushing teeth

# %% [markdown]
# Apparently its noise, it corresponds to the question: "\What is/are the __ doing?", which refers to the ``Activity`` attribute

# %%
query_atts = set([att if att not in ['15', '16', '18', '24', '25', '27', '31'] else 'activity' for att in temp['query']])

# %%
# attribites in query primitive that not appear in the rest
for a in query_atts:
    primitives_and_attributes['query'].add(a)
    if a not in all_attributes:
        print(a)
        all_attributes.add(a)

primitives_and_attributes['same'].update(temp['same'])
primitives_and_attributes['different'].update(temp['different'])
# Out:
# face expression

# %% [markdown]
# This one didnt exist in the other primitives, so we added it, together with missing ```same/different``` concepts. Let's see everything again now:

# %%
for fn, atts in primitives_and_attributes.items():
        if atts:
            print(f"{fn} ({len(atts)})\n{','.join(sorted(atts))}")
            print()
# Out:
# choose (44)
# activity,age,brightness,cleanliness,color,company,depth,face,fatness,flavor,gender,hardness,healthier,height,hposition,larger,length,less,location,lower,material,name,older,opaqness,pattern,place,pose,race,realism,rel,shape,shorter,size,smaller,sportActivity,state,taller,thickness,tone,vposition,weather,weight,width,younger
#
# verify (37)
# activity,age,brightness,cleanliness,color,company,depth,face,fatness,flavor,gender,hardness,height,hposition,length,location,material,opaqness,pattern,place,pose,race,realism,rel,room,shape,size,sportActivity,state,texture,thickness,tone,type,vposition,weather,weight,width
#
# filter (37)
# activity,age,brightness,cleanliness,color,company,depth,event,face,fatness,flavor,gender,hardness,height,hposition,length,liquid,material,opaqness,orientation,pattern,pose,race,realism,room,shape,size,sport,sportActivity,state,texture,thickness,tone,vposition,weather,weight,width
#
# same (5)
# color,gender,material,shape,type
#
# different (4)
# color,gender,shape,type
#
# query (33)
# activity,age,cleanliness,color,company,depth,face expression,fatness,flavor,gender,hardness,height,hposition,length,material,name,pattern,place,pose,race,realism,room,shape,size,sport,sportActivity,state,texture,thickness,tone,weather,weight,width

# %% [markdown]
# Let's check out the ```relate``` primitive. It's also associated with some type of relational concepts.

# %%
relate_concepts = set()
for _, sample in ds.items():
    ops = [fn['operation'] for fn in sample['semantic']]
    if 'relate' in ops:
        # avoid ground truth tag for image
        arg = sample['semantic'][ops.index('relate')]['argument'].split(' (')[0]
        # first field corresponds to the subject. Its used for verifying relations
        subj, concept, sth = arg.split(',')
        relate_concepts.add(concept)
#         if len(arg.split(',')) < 3:
#             print_qa(sample)
#             print(arg.split(','))

pprint(relate_concepts)
# Out:
# {'about to hit',
#  'above',
#  'across',
#  'adjusting',
#  'along',
#  'approaching',
#  'around',
#  'at',
#  'at the edge of',
#  'attached to',
#  'balancing on',
#  'behind',
#  'below',
#  'beneath',
#  'beside',
#  'between',
#  'beyond',
#  'biting',
#  'blowing out',
#  'boarding',
#  'brushing',
#  'buying',
#  'by',
#  'carrying',
#  'catching',
#  'chained to',
#  'chasing',
#  'chewing',
#  'cleaning',
#  'climbing',
#  'close to',
#  'coming down',
#  'coming from',
#  'coming out of',
#  'connected to',
#  'contain',
#  'cooked in',
#  'cooking',
#  'covered by',
#  'covered in',
#  'covered with',
#  'covering',
#  'crossing',
#  'cutting',
#  'decorated by',
#  'decorated with',
#  'decorating',
#  'displayed in',
#  'displayed on',
#  'down',
#  'dragging',
#  'draped over',
#  'drawn on',
#  'drinking',
#  'drinking from',
#  'driving',
#  'driving down',
#  'driving on',
#  'eating',
#  'eating at',
#  'eating from',
#  'eating in',
#  'enclosing',
#  'entering',
#  'exiting',
#  'facing',
#  'falling off',
#  'feeding',
#  'filled with',
#  'floating in',
#  'floating on',
#  'flying',
#  'flying above',
#  'flying in',
#  'flying over',
#  'flying through',
#  'followed by',
#  'following',
#  'full of',
#  'getting on',
#  'going down',
#  'going into',
#  'going through',
#  'grabbing',
#  'grazing in',
#  'grazing on',
#  'growing along',
#  'growing behind',
#  'growing by',
#  'growing from',
#  'growing in',
#  'growing near',
#  'growing next to',
#  'growing on',
#  'guiding',
#  'hang from',
#  'hanging above',
#  'hanging from',
#  'hanging in',
#  'hanging off',
#  'hanging on',
#  'hanging out of',
#  'hanging over',
#  'helping',
#  'herding',
#  'hidden by',
#  'higher than',
#  'hitting',
#  'holding',
#  'holding onto',
#  'hugging',
#  'hung on',
#  'in',
#  'in between',
#  'in front of',
#  'in the center of',
#  'in the middle of',
#  'inside',
#  'jumping off',
#  'jumping on',
#  'jumping over',
#  'kept in',
#  'kicking',
#  'kissing',
#  'larger than',
#  'leading',
#  'leaning against',
#  'leaning on',
#  'leaning over',
#  'leaving',
#  'licking',
#  'longer than',
#  'looking at',
#  'looking down at',
#  'looking for',
#  'looking in',
#  'looking into',
#  'looking out',
#  'looking over',
#  'looking through',
#  'looking toward',
#  'lying in',
#  'lying inside',
#  'lying next to',
#  'lying on',
#  'lying on top of',
#  'making',
#  'mixed with',
#  'mounted on',
#  'mounted to',
#  'moving',
#  'near',
#  'next to',
#  'observing',
#  'of',
#  'on',
#  'on the back of',
#  'on the bottom of',
#  'on the edge of',
#  'on the front of',
#  'on the other side of',
#  'on the side of',
#  'on top of',
#  'opening',
#  'outside',
#  'over',
#  'painted on',
#  'parked along',
#  'parked alongside',
#  'parked at',
#  'parked behind',
#  'parked beside',
#  'parked by',
#  'parked in',
#  'parked in front of',
#  'parked near',
#  'parked next to',
#  'parked on',
#  'perched on',
#  'petting',
#  'photographing',
#  'picking up',
#  'piled on',
#  'placed on',
#  'playing',
#  'playing at',
#  'playing in',
#  'playing on',
#  'playing with',
#  'plugged into',
#  'pointing at',
#  'pointing to',
#  'posing with',
#  'pouring',
#  'preparing',
#  'printed on',
#  'pulled by',
#  'pulling',
#  'pushed by',
#  'pushing',
#  'reaching for',
#  'reading',
#  'reflected in',
#  'reflected on',
#  'reflecting in',
#  'resting on',
#  'riding',
#  'riding in',
#  'riding on',
#  'running across',
#  'running in',
#  'running on',
#  'running through',
#  'same color',
#  'same material',
#  'same shape',
#  'scattered on',
#  'seen through',
#  'selling',
#  'served on',
#  'serving',
#  'sewn on',
#  'shining through',
#  'shorter than',
#  'sitting around',
#  'sitting at',
#  'sitting atop',
#  'sitting behind',
#  'sitting beside',
#  'sitting by',
#  'sitting in',
#  'sitting in front of',
#  'sitting inside',
#  'sitting near',
#  'sitting next to',
#  'sitting on',
#  'sitting on top of',
#  'sitting under',
#  'sitting with',
#  'skating on',
#  'skiing down',
#  'skiing in',
#  'skiing on',
#  'sleeping in',
#  'sleeping on',
#  'slicing',
#  'smaller than',
#  'smelling',
#  'smiling at',
#  'smoking',
#  'sniffing',
#  'splashing',
#  'sprinkled on',
#  'stacked on',
#  'standing against',
#  'standing around',
#  'standing at',
#  'standing behind',
#  'standing beside',
#  'standing by',
#  'standing in',
#  'standing in front of',
#  'standing near',
#  'standing next to',
#  'standing on',
#  'standing on top of',
#  'standing under',
#  'staring at',
#  'sticking out of',
#  'stuck in',
#  'stuck on',
#  'surrounded by',
#  'surrounding',
#  'swimming in',
#  'swinging',
#  'talking on',
#  'talking to',
#  'taller than',
#  'throwing',
#  'tied around',
#  'tied to',
#  'to the left of',
#  'to the right of',
#  'topped with',
#  'tossing',
#  'touching',
#  'towing',
#  'traveling down',
#  'traveling on',
#  'trying to catch',
#  'tying',
#  'typing on',
#  'under',
#  'underneath',
#  'using',
#  'wading in',
#  'waiting for',
#  'walking across',
#  'walking along',
#  'walking behind',
#  'walking by',
#  'walking down',
#  'walking in',
#  'walking into',
#  'walking near',
#  'walking next to',
#  'walking on',
#  'walking past',
#  'walking through',
#  'walking to',
#  'walking toward',
#  'walking towards',
#  'walking up',
#  'walking with',
#  'washing',
#  'watching',
#  'wearing',
#  'with',
#  'working in',
#  'working on',
#  'worn around',
#  'worn on',
#  'wrapped around',
#  'wrapped in'}

# %% [markdown]
# These are pretty generic. Let's consider them as concept values of the ``rel`` concept also included as attribute.
#
# What are the concept values for all other attribute concepts?

# %%
attribute_values = {**{a: set() for a in all_attributes}, 'generic': set()} 

for _, sample in ds.items():
    ops = [fn['operation'] for fn in sample['semantic']]
    for node in sample['semantic']:
        fn = node['operation']
        arg = node['argument']
        
        # adapt arg for rels
        if len(fn.split()) == 2 and fn.split()[1] == "rel":
                   arg = arg.split(' (')[0].split(',')[1]
        
        # not(x) -> x
        if arg.startswith('not'):
            arg = arg[4:-1]
        
        if fn in ['filter', 'verify', 'same', 'different']:
                   attribute_values['generic'].add(arg.strip())
                   
        elif fn.startswith('filter') or fn.startswith('verify') or fn.startswith('same') or fn.startswith('different'):
                   attribute = fn.split()[1]
                   assert attribute in all_attributes
                   attribute_values[attribute].add(arg.strip())
        
        elif fn.startswith('choose'):
                   check = fn.split()
                   args = set([x.strip() for x in arg.split('|')])
                   if len(check) == 1:
                        attribute_values['generic'].update(args)
                   else:
                       attribute = fn.split()[1]
                       assert attribute in all_attributes
                       attribute_values[attribute].update(args)

pprint(attribute_values)
# making sure our attributes as computed here agree with before
print(len(attribute_values), len(all_attributes))
print((set(attribute_values.keys()).difference(all_attributes)))
# Out:
# {'activity': {'cooking',
#               'drinking',
#               'driving',
#               'eating',
#               'having meeting',
#               'looking down',
#               'looking up',
#               'playing',
#               'posing',
#               'reading',
#               'resting',
#               'sleeping',
#               'staring',
#               'talking',
#               'waiting'},
#  'age': {'young', 'old', 'little'},
#  'brightness': {'dark', 'bright'},
#  'cleanliness': {'stained', 'tinted', 'dirty', 'clean'},
#  'color': {'',
#            'beige',
#            'black',
#            'blond',
#            'blue',
#            'brown',
#            'brunette',
#            'cream colored',
#            'dark',
#            'dark blue',
#            'dark brown',
#            'gold',
#            'gray',
#            'green',
#            'khaki',
#            'light blue',
#            'light brown',
#            'maroon',
#            'orange',
#            'pink',
#            'purple',
#            'red',
#            'silver',
#            'tan',
#            'teal',
#            'white',
#            'yellow'},
#  'company': {'nike', 'adidas'},
#  'depth': {'deep', 'shallow'},
#  'event': {'birthday', 'wedding', 'christmas'},
#  'face': {'happy', 'angry', 'unhappy', 'sad'},
#  'face expression': set(),
#  'fatness': {'skinny', 'fat', 'thin'},
#  'flavor': {'chocolate', 'vanilla', 'cheese', 'strawberry'},
#  'gender': {'female', 'male'},
#  'generic': {'abandoned',
#              'abundant',
#              'adult',
#              'alert',
#              'american',
#              'analog',
#              'angled',
#              'antique',
#              'apple',
#              'arched',
#              'artificial',
#              'assorted',
#              'athletic',
#              'attached',
#              'baby',
#              'baked',
#              'bald',
#              'balding',
#              'banana',
#              'bare',
#              'barefoot',
#              'barren',
#              'baseball',
#              'beautiful',
#              'bent',
#              'black and white',
#              'blank',
#              'blooming',
#              'blowing',
#              'blurry',
#              'boiled',
#              'breaking',
#              'bright',
#              'broken',
#              'browned',
#              'brushing teeth',
#              'bunched',
#              'burning',
#              'burnt',
#              'bushy',
#              'busy',
#              'calico',
#              'carved',
#              'cast on shadow',
#              'ceramic',
#              'chinese',
#              'chipped',
#              'chopped',
#              'chubby',
#              'clear',
#              'closed',
#              'clumped',
#              'cluttered',
#              'collared',
#              'colorful',
#              'comfortable',
#              'commercial',
#              'complete',
#              'computer',
#              'connected',
#              'cooked',
#              'cordless',
#              'covered',
#              'cracked',
#              'creamy',
#              'crisp',
#              'crispy',
#              'crooked',
#              'crossed',
#              'crowded',
#              'crumbled',
#              'crumpled',
#              'crusty',
#              'curious',
#              'curled',
#              'curly',
#              'curved',
#              'curvy',
#              'cushioned',
#              'cut',
#              'cylindrical',
#              'damaged',
#              'dark',
#              'dark colored',
#              'deciduous',
#              'decorated',
#              'decorative',
#              'delicious',
#              'dense',
#              'designed',
#              'diced',
#              'digital',
#              'displayed',
#              'disposable',
#              'docked',
#              'double decker',
#              'down',
#              'drawn',
#              'dressed in black',
#              'dressed in blue',
#              'dressed in brown',
#              'dressed in gray',
#              'dressed in green',
#              'dressed in light blue',
#              'dressed in maroon',
#              'dressed in orange',
#              'dressed in pink',
#              'dressed in purple',
#              'dressed in red',
#              'dressed in tan',
#              'dressed in white',
#              'dressed in yellow',
#              'dried',
#              'dry',
#              'dull',
#              'dusty',
#              'eaten',
#              'edged',
#              'elderly',
#              'electric',
#              'electronic',
#              'elevated',
#              'elongated',
#              'empty',
#              'evergreen',
#              'facing away',
#              'facing front',
#              'facing left',
#              'facing right',
#              'faded',
#              'fallen',
#              'fancy',
#              'feathered',
#              'fenced',
#              'filled',
#              'fire',
#              'flat',
#              'floating',
#              'floppy',
#              'floral',
#              'flowered',
#              'fluffy',
#              'fluorescent',
#              'flying',
#              'folded',
#              'folding',
#              'foreign',
#              'forested',
#              'formal',
#              'framed',
#              'french',
#              'fresh',
#              'fried',
#              'frosted',
#              'frozen',
#              'full',
#              'funny',
#              'furry',
#              'fuzzy',
#              'gas',
#              'gender',
#              'glazed',
#              'glossy',
#              'glowing',
#              'grassy',
#              'grated',
#              'gravel',
#              'grazing',
#              'greasy',
#              'grilled',
#              'groomed',
#              'grouped',
#              'hairy',
#              'half full',
#              'halved',
#              'handmade',
#              'hanging',
#              'healthy',
#              'high',
#              'hitting',
#              'hollow',
#              'homemade',
#              'iced',
#              'illuminated',
#              'immature',
#              'incomplete',
#              'indoors',
#              'industrial',
#              'inflatable',
#              'inflated',
#              'irregular',
#              'ivory',
#              'jagged',
#              'jeans',
#              'juicy',
#              'kneeling',
#              'knit',
#              'laughing',
#              'leafless',
#              'leafy',
#              'light',
#              'light colored',
#              'lighted',
#              'lined',
#              'lit',
#              'little',
#              'long sleeved',
#              'looking ahead',
#              'looking at the camera',
#              'looking away',
#              'looking back',
#              'looking behind',
#              'looking downward',
#              'looking for food',
#              'looking for the luggage',
#              'looking for the shoe',
#              'looking forward',
#              'looking in the mirror',
#              'looking left',
#              'looking out',
#              'looking outside',
#              'looking right',
#              'looking sideways',
#              'looking straight',
#              'looking upwards',
#              'loose',
#              'low',
#              'lower',
#              'lush',
#              'made',
#              'making a face',
#              'massive',
#              'mature',
#              'melted',
#              'melting',
#              'messy',
#              'military',
#              'miniature',
#              'mixed',
#              'modern',
#              'mounted',
#              'mowed',
#              'muddy',
#              'murky',
#              'muscular',
#              'navy',
#              'neat',
#              'neon',
#              'new',
#              'oblong',
#              'off',
#              'old',
#              'old fashioned',
#              'on',
#              'open',
#              'oriental',
#              'ornamental',
#              'ornate',
#              'outdoor',
#              'outdoors',
#              'overgrown',
#              'overhead',
#              'oversized',
#              'packaged',
#              'packed',
#              'padded',
#              'painted',
#              'pale',
#              'paneled',
#              'park',
#              'parked',
#              'pastel',
#              'patched',
#              'patchy',
#              'patterned',
#              'paved',
#              'peeled',
#              'pepper',
#              'perched',
#              'piled',
#              'pizza',
#              'plaid',
#              'plain',
#              'playing baseball',
#              'playing basketball',
#              'playing cricket',
#              'playing football',
#              'playing frisbee',
#              'playing games',
#              'playing soccer',
#              'playing tennis',
#              'playing video games',
#              'playing volleyball',
#              'playing wii',
#              'plush',
#              'pointing up',
#              'pointy',
#              'polar',
#              'polished',
#              'polo',
#              'portable',
#              'potted',
#              'powdered',
#              'powerful',
#              'pretty',
#              'printed',
#              'professional',
#              'protective',
#              'public',
#              'puffy',
#              'pulled back',
#              'quilted',
#              'railroad',
#              'rainbow colored',
#              'raised',
#              'raw',
#              'reflected',
#              'reflective',
#              'regular',
#              'ridged',
#              'ripe',
#              'rippled',
#              'rippling',
#              'roasted',
#              'rocky',
#              'rolled',
#              'rotten',
#              'rounded',
#              'ruffled',
#              'rugged',
#              'rustic',
#              'rusty',
#              'safety',
#              'sandy',
#              'scarce',
#              'scattered',
#              'scrambled',
#              'sculpted',
#              'sealed',
#              'seasoned',
#              'shaded',
#              'shadowed',
#              'shaggy',
#              'shaking hands',
#              'shaped',
#              'sharp',
#              'shaved',
#              'sheer',
#              'shining',
#              'shiny',
#              'shirtless',
#              'short',
#              'short sleeved',
#              'shredded',
#              'shut',
#              'slanted',
#              'sleepy',
#              'sleeveless',
#              'sliced',
#              'sliding',
#              'smiling',
#              'snow',
#              'snowy',
#              'soccer',
#              'sparse',
#              'speckled',
#              'spiky',
#              'spiral',
#              'splashing',
#              'spraying',
#              'spread',
#              'sprinkled',
#              'squatting',
#              'stacked',
#              'steamed',
#              'steep',
#              'straight',
#              'street',
#              'strong',
#              'stuffed',
#              'sturdy',
#              'sunlit',
#              'support',
#              'suspended',
#              'sweet',
#              'swinging',
#              'tabby',
#              'tail',
#              'taking a photo',
#              'taking a photograph',
#              'taking a picture',
#              'taking bath',
#              'taking pictures',
#              'tangled',
#              'tasty',
#              'tennis',
#              'textured',
#              'thin',
#              'tied',
#              'tight',
#              'tiled',
#              'tilted',
#              'toasted',
#              'tomato',
#              'torn',
#              'toy',
#              'traffic',
#              'translucent',
#              'transparent',
#              'trash',
#              'trimmed',
#              'tropical',
#              'turned',
#              'twisted',
#              'type',
#              'typical',
#              'ugly',
#              'uncomfortable',
#              'uncooked',
#              'uneven',
#              'unhealthy',
#              'unlit',
#              'unoccupied',
#              'unpaved',
#              'unpeeled',
#              'unripe',
#              'up',
#              'upholstered',
#              'upper',
#              'upside down',
#              'used',
#              'vacant',
#              'vast',
#              'vintage',
#              'vinyl',
#              'warm',
#              'waving',
#              'weathered',
#              'wet',
#              'wii',
#              'wild',
#              'winter',
#              'wired',
#              'wireless',
#              'wispy',
#              'wooded',
#              'worn',
#              'woven',
#              'wrapped',
#              'wrinkled',
#              'wrinkly',
#              'written'},
#  'hardness': {'soft', 'hard'},
#  'healthier': {''},
#  'height': {'short', 'tall'},
#  'hposition': {'right', 'left'},
#  'larger': {''},
#  'length': {'short', 'long'},
#  'less': {''},
#  'liquid': {'beer', 'coffee', 'water', 'wine', 'soda'},
#  'location': {'indoors', 'outdoors'},
#  'lower': {''},
#  'material': {'',
#               'aluminum',
#               'asphalt',
#               'bamboo',
#               'brass',
#               'brick',
#               'bronze',
#               'cardboard',
#               'chrome',
#               'clay',
#               'cloth',
#               'cobblestone',
#               'concrete',
#               'copper',
#               'cotton',
#               'crystal',
#               'denim',
#               'glass',
#               'granite',
#               'hardwood',
#               'iron',
#               'lace',
#               'leather',
#               'marble',
#               'mesh',
#               'metal',
#               'paper',
#               'plastic',
#               'porcelain',
#               'rock',
#               'rubber',
#               'silk',
#               'stainless steel',
#               'steel',
#               'stone',
#               'straw',
#               'styrofoam',
#               'tin',
#               'wicker',
#               'wire',
#               'wood',
#               'wool'},
#  'name': {'air conditioner',
#           'airplane',
#           'almonds',
#           'ambulance',
#           'ambulances',
#           'antelope',
#           'antelopes',
#           'apple',
#           'apples',
#           'apron',
#           'armchair',
#           'artichoke',
#           'asparagus',
#           'avocado',
#           'backpack',
#           'bacon',
#           'bagel',
#           'baking sheet',
#           'ball',
#           'balloon',
#           'banana',
#           'bananas',
#           'bar stool',
#           'baseball',
#           'baseball bats',
#           'basil',
#           'bat',
#           'beans',
#           'bear',
#           'bears',
#           'bed',
#           'bee',
#           'beef',
#           'beer',
#           'beet',
#           'beets',
#           'bell tower',
#           'bell towers',
#           'berries',
#           'berry',
#           'bicycle',
#           'bicycles',
#           'bike',
#           'bikes',
#           'bikini',
#           'bird',
#           'birds',
#           'biscuit',
#           'bison',
#           'blanket',
#           'blazer',
#           'blender',
#           'blouse',
#           'blueberries',
#           'blueberry',
#           'boar',
#           'boars',
#           'boat',
#           'bookcase',
#           'bookshelf',
#           'bottle',
#           'bread',
#           'briefcase',
#           'broccoli',
#           'broth',
#           'brownie',
#           'brownies',
#           'bull',
#           'bun',
#           'bunny',
#           'burger',
#           'burrito',
#           'bus',
#           'buses',
#           'butterfly',
#           'cabbage',
#           'cabinet',
#           'cabinets',
#           'cake',
#           'calculator',
#           'calf',
#           'camel',
#           'camera',
#           'can',
#           'candy',
#           'canoe',
#           'cap',
#           'car',
#           'carriage',
#           'carrot',
#           'carrots',
#           'cars',
#           'castle',
#           'castles',
#           'cat',
#           'cats',
#           'cauliflower',
#           'celery',
#           'cell phone',
#           'cell phones',
#           'cereal',
#           'chair',
#           'chairs',
#           'charger',
#           'cheese',
#           'cheesecake',
#           'cheesecakes',
#           'cheetah',
#           'chef hat',
#           'cherries',
#           'cherry',
#           'chicken breast',
#           'chili',
#           'chinese food',
#           'chocolate',
#           'clock tower',
#           'closet',
#           'coat',
#           'coconut',
#           'coffee',
#           'coffee maker',
#           'coffee pot',
#           'coffee table',
#           'coleslaw',
#           'computer',
#           'computer desk',
#           'computer monitor',
#           'computer mouse',
#           'computer mouses',
#           'console',
#           'controller',
#           'cooker',
#           'cookie',
#           'cookies',
#           'corn',
#           'costume',
#           'couch',
#           'cow',
#           'cowboy hat',
#           'cows',
#           'cracker',
#           'cranberries',
#           'croissant',
#           'croissants',
#           'cucumber',
#           'cucumbers',
#           'cup',
#           'cupboard',
#           'cupboards',
#           'cupcake',
#           'cupcakes',
#           'cutting board',
#           'deer',
#           'desk',
#           'dessert',
#           'dining table',
#           'dinosaur',
#           'dinosaurs',
#           'dip',
#           'dishwasher',
#           'dog',
#           'dogs',
#           'doll',
#           'dolphin',
#           'dolphins',
#           'donkey',
#           'donkeys',
#           'donut',
#           'donuts',
#           'dragon',
#           'dragons',
#           'drawer',
#           'drawers',
#           'dress',
#           'dress shirt',
#           'dresser',
#           'drum',
#           'duck',
#           'ducks',
#           'dvd player',
#           'dvd players',
#           'eagle',
#           'eagles',
#           'egg',
#           'eggplant',
#           'eggs',
#           'elephant',
#           'elephants',
#           'end table',
#           'entertainment center',
#           'fire hydrant',
#           'fire truck',
#           'fire trucks',
#           'flag',
#           'flamingo',
#           'food processor',
#           'food trucks',
#           'football',
#           'fork',
#           'fries',
#           'frisbee',
#           'frog',
#           'fruit',
#           'fruits',
#           'game controller',
#           'garlic',
#           'garment',
#           'gas stove',
#           'giraffe',
#           'giraffes',
#           'glove',
#           'gloves',
#           'goat',
#           'goats',
#           'goose',
#           'gown',
#           'grape',
#           'grapefruit',
#           'grapes',
#           'gravy',
#           'guitar',
#           'gun',
#           'hair dryer',
#           'ham',
#           'hamburger',
#           'hamburgers',
#           'hat',
#           'headphones',
#           'heater',
#           'helicopter',
#           'herb',
#           'hippo',
#           'hippos',
#           'horse',
#           'horses',
#           'hot dog',
#           'hot dogs',
#           'hotdog bun',
#           'ice cream',
#           'ice maker',
#           'ipod',
#           'jacket',
#           'jackets',
#           'jeans',
#           'jeep',
#           'jersey',
#           'juice',
#           'jumpsuit',
#           'ketchup',
#           'kettle',
#           'keyboard',
#           'keyboards',
#           'kite',
#           'kitten',
#           'kittens',
#           'kiwi',
#           'knife',
#           'ladle',
#           'lamb',
#           'lambs',
#           'lamp',
#           'laptop',
#           'laptops',
#           'lemon',
#           'lemons',
#           'lettuce',
#           'lime',
#           'lion',
#           'lions',
#           'lizard',
#           'loaf',
#           'lobster',
#           'locomotive',
#           'macaroni',
#           'mango',
#           'mangoes',
#           'marshmallow',
#           'mashed potatoes',
#           'meat',
#           'meatballs',
#           'medicine cabinet',
#           'melon',
#           'melons',
#           'men',
#           'microphone',
#           'microwave',
#           'microwave oven',
#           'milk',
#           'minivan',
#           'mirror',
#           'mixer',
#           'mixing bowl',
#           'monitor',
#           'monkey',
#           'monkeys',
#           'moose',
#           'motorcycle',
#           'motorcycles',
#           'mozzarella',
#           'muffin',
#           'muffins',
#           'mug',
#           'mushroom',
#           'mushrooms',
#           'mustard',
#           'nightstand',
#           'noodles',
#           'nut',
#           'nuts',
#           'oatmeal',
#           'octopus',
#           'office chair',
#           'olive',
#           'olives',
#           'omelette',
#           'onion',
#           'onion ring',
#           'onion rings',
#           'onions',
#           'orange',
#           'oranges',
#           'ostrich',
#           'ostriches',
#           'ottoman',
#           'outfit',
#           'outfits',
#           'oven',
#           'owl',
#           'owls',
#           'pajamas',
#           'pan',
#           'pancake',
#           'pancakes',
#           'panda',
#           'panda bear',
#           'panda bears',
#           'pandas',
#           'pants',
#           'parking sign',
#           'parrot',
#           'parrots',
#           'parsley',
#           'pasta',
#           'pasta salad',
#           'pastry',
#           'pea',
#           'peach',
#           'peaches',
#           'peanut',
#           'peanut butter',
#           'peanuts',
#           'pear',
#           'pears',
#           'peas',
#           'penguin',
#           'penguins',
#           'pepper',
#           'pepperoni',
#           'peppers',
#           'phone',
#           'piano',
#           'pickles',
#           'pie',
#           'pig',
#           'pigeon',
#           'pigeons',
#           'pigs',
#           'pillow',
#           'pillows',
#           'pineapple',
#           'pineapples',
#           'pita',
#           'pizza',
#           'pizza oven',
#           'pizza pan',
#           'plantains',
#           'plate',
#           'polar bear',
#           'polo shirt',
#           'pot',
#           'potato',
#           'potatoes',
#           'pouch',
#           'pretzel',
#           'printer',
#           'printers',
#           'projector',
#           'pumpkin',
#           'puppy',
#           'puppys',
#           'purse',
#           'rabbit',
#           'racket',
#           'rackets',
#           'radiator',
#           'raincoat',
#           'raisin',
#           'raisins',
#           'raspberries',
#           'refrigerator',
#           'remote control',
#           'rhino',
#           'rhinos',
#           'ribs',
#           'rice',
#           'roast beef',
#           'robe',
#           'router',
#           'rubber duck',
#           'salad',
#           'sandwich',
#           'sandwiches',
#           'sausage',
#           'sausages',
#           'school bus',
#           'scooter',
#           'scooters',
#           'screen',
#           'seagull',
#           'seagulls',
#           'seal',
#           'seals',
#           'shark',
#           'sharks',
#           'sheep',
#           'shelf',
#           'shelves',
#           'ship',
#           'shirt',
#           'shirts',
#           'shorts',
#           'shrimp',
#           'side table',
#           'skateboard',
#           'skateboarder',
#           'skateboards',
#           'skirt',
#           'skis',
#           'skyscraper',
#           'skyscrapers',
#           'snack',
#           'snacks',
#           'snake',
#           'snakes',
#           'snow pants',
#           'snowboard',
#           'snowboarder',
#           'snowsuit',
#           'soccer ball',
#           'soccer balls',
#           'sock',
#           'socks',
#           'soda',
#           'sofa',
#           'soup',
#           'sour cream',
#           'spatula',
#           'speaker',
#           'speakers',
#           'spider',
#           'spinach',
#           'spoon',
#           'squash',
#           'squirrel',
#           'squirrels',
#           'steak',
#           'stop sign',
#           'stove',
#           'strawberries',
#           'strawberry',
#           'street sign',
#           'stuffed animal',
#           'stuffed bear',
#           'stuffed bears',
#           'suit',
#           'suits',
#           'suv',
#           'swan',
#           'swans',
#           'sweater',
#           'sweatshirt',
#           'sweet potato',
#           'sweet potatoes',
#           'sword',
#           't-shirt',
#           'table',
#           'tables',
#           'tablet',
#           'taco',
#           'tank top',
#           'taxi',
#           'taxis',
#           'tea',
#           'tea kettle',
#           'tea pot',
#           'teddy bear',
#           'television',
#           'televisions',
#           'tennis ball',
#           'tennis balls',
#           'tiger',
#           'toast',
#           'toaster',
#           'toaster oven',
#           'toasts',
#           'tofu',
#           'tomato',
#           'tomatoes',
#           'tortilla',
#           'towel',
#           'toy car',
#           'tractor',
#           'tractors',
#           'traffic light',
#           'traffic sign',
#           'trailer',
#           'train',
#           'train car',
#           'trains',
#           'truck',
#           'trucks',
#           'trumpet',
#           'trunks',
#           'tv stand',
#           'undershirt',
#           'uniform',
#           'van',
#           'vegetable',
#           'vegetables',
#           'vest',
#           'vests',
#           'waffle',
#           'waffles',
#           'wagon',
#           'wardrobe',
#           'washing machine',
#           'watermelon',
#           'wetsuit',
#           'whisk',
#           'wii',
#           'wii controller',
#           'wii controllers',
#           'wine',
#           'wine glass',
#           'wolf',
#           'wolves',
#           'women',
#           'xbox controller',
#           'xbox controllers',
#           'yogurt',
#           'zebra',
#           'zebras',
#           'zucchini'},
#  'older': {''},
#  'opaqness': {'clear', 'opaque'},
#  'orientation': {'horizontal', 'vertical'},
#  'pattern': {'striped', 'checkered', 'dotted'},
#  'place': {'airport',
#            'bathroom',
#            'beach',
#            'bedroom',
#            'church',
#            'city',
#            'desert',
#            'dining room',
#            'farm',
#            'field',
#            'forest',
#            'garage',
#            'garden',
#            'hallway',
#            'harbor',
#            'hotel',
#            'kitchen',
#            'lake',
#            'library',
#            'living room',
#            'marina',
#            'market',
#            'museum',
#            'ocean',
#            'office',
#            'park',
#            'parking lot',
#            'pond',
#            'restaurant',
#            'river',
#            'shop',
#            'store',
#            'theater',
#            'train station',
#            'village',
#            'zoo'},
#  'pose': {'bending',
#           'crouching',
#           'jumping',
#           'lying',
#           'pointing',
#           'running',
#           'sitting',
#           'standing',
#           'walking'},
#  'race': {'asian', 'caucasian'},
#  'realism': {'fake', 'real'},
#  'rel': {'about to hit',
#          'above',
#          'adjusting',
#          'approaching',
#          'around',
#          'attached to',
#          'balancing on',
#          'behind',
#          'below',
#          'beneath',
#          'between',
#          'biting',
#          'boarding',
#          'brushing',
#          'buying',
#          'carrying',
#          'catching',
#          'chasing',
#          'chewing',
#          'cleaning',
#          'climbing',
#          'coming from',
#          'coming out of',
#          'connected to',
#          'contain',
#          'cooked in',
#          'cooking',
#          'covered by',
#          'covered in',
#          'covered with',
#          'covering',
#          'crossing',
#          'cutting',
#          'decorated by',
#          'decorated with',
#          'decorating',
#          'displayed on',
#          'dragging',
#          'draped over',
#          'drinking',
#          'drinking from',
#          'driving',
#          'driving on',
#          'eating',
#          'eating at',
#          'eating from',
#          'enclosing',
#          'entering',
#          'exiting',
#          'facing',
#          'falling off',
#          'feeding',
#          'filled with',
#          'floating in',
#          'floating on',
#          'flying',
#          'flying above',
#          'flying in',
#          'flying over',
#          'flying through',
#          'followed by',
#          'following',
#          'full of',
#          'getting on',
#          'going down',
#          'going into',
#          'going through',
#          'grabbing',
#          'grazing on',
#          'growing behind',
#          'growing by',
#          'growing on',
#          'guiding',
#          'hang from',
#          'hanging above',
#          'hanging from',
#          'hanging in',
#          'hanging off',
#          'hanging on',
#          'hanging out of',
#          'hanging over',
#          'helping',
#          'herding',
#          'hidden by',
#          'hitting',
#          'holding',
#          'holding onto',
#          'hugging',
#          'hung on',
#          'in',
#          'in front of',
#          'inside',
#          'jumping off',
#          'jumping on',
#          'jumping over',
#          'kept in',
#          'kicking',
#          'kissing',
#          'leading',
#          'leaning against',
#          'leaning on',
#          'leaning over',
#          'leaving',
#          'licking',
#          'looking',
#          'looking at',
#          'looking down at',
#          'looking in',
#          'looking into',
#          'looking out',
#          'looking over',
#          'looking through',
#          'lying in',
#          'lying inside',
#          'lying next to',
#          'lying on',
#          'lying on top of',
#          'making',
#          'mixed with',
#          'mounted on',
#          'mounted to',
#          'moving',
#          'observing',
#          'on',
#          'on the edge of',
#          'on top of',
#          'opening',
#          'painted on',
#          'parked at',
#          'parked behind',
#          'parked beside',
#          'parked by',
#          'parked in',
#          'parked in front of',
#          'parked near',
#          'parked next to',
#          'parked on',
#          'perched on',
#          'petting',
#          'photographing',
#          'picking up',
#          'piled on',
#          'playing',
#          'playing in',
#          'playing on',
#          'playing with',
#          'plugged into',
#          'pointing at',
#          'posing with',
#          'pouring',
#          'preparing',
#          'printed on',
#          'pulled by',
#          'pulling',
#          'pushed by',
#          'pushing',
#          'reaching for',
#          'reading',
#          'reflected in',
#          'reflected on',
#          'reflecting in',
#          'resting on',
#          'riding',
#          'riding in',
#          'riding on',
#          'running across',
#          'running in',
#          'running on',
#          'running through',
#          'scattered on',
#          'seen through',
#          'selling',
#          'served on',
#          'serving',
#          'shining through',
#          'shorter than',
#          'sitting at',
#          'sitting atop',
#          'sitting behind',
#          'sitting beside',
#          'sitting by',
#          'sitting in',
#          'sitting in front of',
#          'sitting inside',
#          'sitting near',
#          'sitting next to',
#          'sitting on',
#          'sitting on top of',
#          'sitting under',
#          'sitting with',
#          'skating on',
#          'skiing in',
#          'skiing on',
#          'sleeping in',
#          'sleeping on',
#          'slicing',
#          'smelling',
#          'smiling at',
#          'smoking',
#          'sniffing',
#          'sprinkled on',
#          'stacked on',
#          'standing against',
#          'standing at',
#          'standing behind',
#          'standing beside',
#          'standing by',
#          'standing in',
#          'standing in front of',
#          'standing near',
#          'standing next to',
#          'standing on',
#          'standing on top of',
#          'standing under',
#          'staring at',
#          'stuck in',
#          'stuck on',
#          'surrounded by',
#          'surrounding',
#          'swimming in',
#          'swinging',
#          'talking on',
#          'talking to',
#          'taller than',
#          'throwing',
#          'tied around',
#          'tied to',
#          'to the left of',
#          'to the right of',
#          'topped with',
#          'tossing',
#          'touching',
#          'towing',
#          'traveling on',
#          'trying to catch',
#          'tying',
#          'typing on',
#          'under',
#          'underneath',
#          'using',
#          'waiting for',
#          'walking along',
#          'walking behind',
#          'walking by',
#          'walking down',
#          'walking in',
#          'walking near',
#          'walking next to',
#          'walking on',
#          'walking past',
#          'walking to',
#          'walking toward',
#          'walking towards',
#          'walking with',
#          'washing',
#          'watching',
#          'wearing',
#          'working in',
#          'working on',
#          'worn around',
#          'worn on',
#          'wrapped around',
#          'wrapped in'},
#  'room': {'living room', 'bathroom', 'dining room', 'kitchen', 'office'},
#  'shape': {'', 'octagonal', 'square', 'round', 'rectangular', 'triangular'},
#  'shorter': {''},
#  'size': {'large', 'tiny', 'small', 'huge', 'little', 'giant'},
#  'smaller': {''},
#  'sport': {'baseball', 'ski', 'tennis', 'soccer'},
#  'sportActivity': {'performing trick',
#                    'riding',
#                    'skateboarding',
#                    'skating',
#                    'skiing',
#                    'snowboarding',
#                    'surfing',
#                    'swimming'},
#  'state': {'choppy', 'smooth', 'still', 'wavy', 'rough', 'calm'},
#  'taller': {''},
#  'texture': {'fine', 'coarse'},
#  'thickness': {'thick', 'thin'},
#  'tone': {'light', 'dark'},
#  'type': {'baseball', 'tennis', 'soccer'},
#  'vposition': {'bottom', 'middle', 'top'},
#  'weather': {'clear',
#              'cloudless',
#              'cloudy',
#              'foggy',
#              'overcast',
#              'partly cloudy',
#              'rainy',
#              'stormy',
#              'sunny'},
#  'weight': {'light', 'heavy'},
#  'width': {'wide', 'narrow'},
#  'younger': {''}}
# 53 52
# {'generic'}

# %% [markdown]
# The only difference is the ``generic`` concept, which we defined ourselves above. This covers all cases where primitives (e.g. ``filter, query, same`` etc.) where not followed by a specific attribute, so we organize them together. The ``generic`` attribute values are in the long-tail:

# %%
pprint(attribute_values['generic'])
# Out:
# {'abandoned',
#  'abundant',
#  'adult',
#  'alert',
#  'american',
#  'analog',
#  'angled',
#  'antique',
#  'apple',
#  'arched',
#  'artificial',
#  'assorted',
#  'athletic',
#  'attached',
#  'baby',
#  'baked',
#  'bald',
#  'balding',
#  'banana',
#  'bare',
#  'barefoot',
#  'barren',
#  'baseball',
#  'beautiful',
#  'bent',
#  'black and white',
#  'blank',
#  'blooming',
#  'blowing',
#  'blurry',
#  'boiled',
#  'breaking',
#  'bright',
#  'broken',
#  'browned',
#  'brushing teeth',
#  'bunched',
#  'burning',
#  'burnt',
#  'bushy',
#  'busy',
#  'calico',
#  'carved',
#  'cast on shadow',
#  'ceramic',
#  'chinese',
#  'chipped',
#  'chopped',
#  'chubby',
#  'clear',
#  'closed',
#  'clumped',
#  'cluttered',
#  'collared',
#  'colorful',
#  'comfortable',
#  'commercial',
#  'complete',
#  'computer',
#  'connected',
#  'cooked',
#  'cordless',
#  'covered',
#  'cracked',
#  'creamy',
#  'crisp',
#  'crispy',
#  'crooked',
#  'crossed',
#  'crowded',
#  'crumbled',
#  'crumpled',
#  'crusty',
#  'curious',
#  'curled',
#  'curly',
#  'curved',
#  'curvy',
#  'cushioned',
#  'cut',
#  'cylindrical',
#  'damaged',
#  'dark',
#  'dark colored',
#  'deciduous',
#  'decorated',
#  'decorative',
#  'delicious',
#  'dense',
#  'designed',
#  'diced',
#  'digital',
#  'displayed',
#  'disposable',
#  'docked',
#  'double decker',
#  'down',
#  'drawn',
#  'dressed in black',
#  'dressed in blue',
#  'dressed in brown',
#  'dressed in gray',
#  'dressed in green',
#  'dressed in light blue',
#  'dressed in maroon',
#  'dressed in orange',
#  'dressed in pink',
#  'dressed in purple',
#  'dressed in red',
#  'dressed in tan',
#  'dressed in white',
#  'dressed in yellow',
#  'dried',
#  'dry',
#  'dull',
#  'dusty',
#  'eaten',
#  'edged',
#  'elderly',
#  'electric',
#  'electronic',
#  'elevated',
#  'elongated',
#  'empty',
#  'evergreen',
#  'facing away',
#  'facing front',
#  'facing left',
#  'facing right',
#  'faded',
#  'fallen',
#  'fancy',
#  'feathered',
#  'fenced',
#  'filled',
#  'fire',
#  'flat',
#  'floating',
#  'floppy',
#  'floral',
#  'flowered',
#  'fluffy',
#  'fluorescent',
#  'flying',
#  'folded',
#  'folding',
#  'foreign',
#  'forested',
#  'formal',
#  'framed',
#  'french',
#  'fresh',
#  'fried',
#  'frosted',
#  'frozen',
#  'full',
#  'funny',
#  'furry',
#  'fuzzy',
#  'gas',
#  'gender',
#  'glazed',
#  'glossy',
#  'glowing',
#  'grassy',
#  'grated',
#  'gravel',
#  'grazing',
#  'greasy',
#  'grilled',
#  'groomed',
#  'grouped',
#  'hairy',
#  'half full',
#  'halved',
#  'handmade',
#  'hanging',
#  'healthy',
#  'high',
#  'hitting',
#  'hollow',
#  'homemade',
#  'iced',
#  'illuminated',
#  'immature',
#  'incomplete',
#  'indoors',
#  'industrial',
#  'inflatable',
#  'inflated',
#  'irregular',
#  'ivory',
#  'jagged',
#  'jeans',
#  'juicy',
#  'kneeling',
#  'knit',
#  'laughing',
#  'leafless',
#  'leafy',
#  'light',
#  'light colored',
#  'lighted',
#  'lined',
#  'lit',
#  'little',
#  'long sleeved',
#  'looking ahead',
#  'looking at the camera',
#  'looking away',
#  'looking back',
#  'looking behind',
#  'looking downward',
#  'looking for food',
#  'looking for the luggage',
#  'looking for the shoe',
#  'looking forward',
#  'looking in the mirror',
#  'looking left',
#  'looking out',
#  'looking outside',
#  'looking right',
#  'looking sideways',
#  'looking straight',
#  'looking upwards',
#  'loose',
#  'low',
#  'lower',
#  'lush',
#  'made',
#  'making a face',
#  'massive',
#  'mature',
#  'melted',
#  'melting',
#  'messy',
#  'military',
#  'miniature',
#  'mixed',
#  'modern',
#  'mounted',
#  'mowed',
#  'muddy',
#  'murky',
#  'muscular',
#  'navy',
#  'neat',
#  'neon',
#  'new',
#  'oblong',
#  'off',
#  'old',
#  'old fashioned',
#  'on',
#  'open',
#  'oriental',
#  'ornamental',
#  'ornate',
#  'outdoor',
#  'outdoors',
#  'overgrown',
#  'overhead',
#  'oversized',
#  'packaged',
#  'packed',
#  'padded',
#  'painted',
#  'pale',
#  'paneled',
#  'park',
#  'parked',
#  'pastel',
#  'patched',
#  'patchy',
#  'patterned',
#  'paved',
#  'peeled',
#  'pepper',
#  'perched',
#  'piled',
#  'pizza',
#  'plaid',
#  'plain',
#  'playing baseball',
#  'playing basketball',
#  'playing cricket',
#  'playing football',
#  'playing frisbee',
#  'playing games',
#  'playing soccer',
#  'playing tennis',
#  'playing video games',
#  'playing volleyball',
#  'playing wii',
#  'plush',
#  'pointing up',
#  'pointy',
#  'polar',
#  'polished',
#  'polo',
#  'portable',
#  'potted',
#  'powdered',
#  'powerful',
#  'pretty',
#  'printed',
#  'professional',
#  'protective',
#  'public',
#  'puffy',
#  'pulled back',
#  'quilted',
#  'railroad',
#  'rainbow colored',
#  'raised',
#  'raw',
#  'reflected',
#  'reflective',
#  'regular',
#  'ridged',
#  'ripe',
#  'rippled',
#  'rippling',
#  'roasted',
#  'rocky',
#  'rolled',
#  'rotten',
#  'rounded',
#  'ruffled',
#  'rugged',
#  'rustic',
#  'rusty',
#  'safety',
#  'sandy',
#  'scarce',
#  'scattered',
#  'scrambled',
#  'sculpted',
#  'sealed',
#  'seasoned',
#  'shaded',
#  'shadowed',
#  'shaggy',
#  'shaking hands',
#  'shaped',
#  'sharp',
#  'shaved',
#  'sheer',
#  'shining',
#  'shiny',
#  'shirtless',
#  'short',
#  'short sleeved',
#  'shredded',
#  'shut',
#  'slanted',
#  'sleepy',
#  'sleeveless',
#  'sliced',
#  'sliding',
#  'smiling',
#  'snow',
#  'snowy',
#  'soccer',
#  'sparse',
#  'speckled',
#  'spiky',
#  'spiral',
#  'splashing',
#  'spraying',
#  'spread',
#  'sprinkled',
#  'squatting',
#  'stacked',
#  'steamed',
#  'steep',
#  'straight',
#  'street',
#  'strong',
#  'stuffed',
#  'sturdy',
#  'sunlit',
#  'support',
#  'suspended',
#  'sweet',
#  'swinging',
#  'tabby',
#  'tail',
#  'taking a photo',
#  'taking a photograph',
#  'taking a picture',
#  'taking bath',
#  'taking pictures',
#  'tangled',
#  'tasty',
#  'tennis',
#  'textured',
#  'thin',
#  'tied',
#  'tight',
#  'tiled',
#  'tilted',
#  'toasted',
#  'tomato',
#  'torn',
#  'toy',
#  'traffic',
#  'translucent',
#  'transparent',
#  'trash',
#  'trimmed',
#  'tropical',
#  'turned',
#  'twisted',
#  'type',
#  'typical',
#  'ugly',
#  'uncomfortable',
#  'uncooked',
#  'uneven',
#  'unhealthy',
#  'unlit',
#  'unoccupied',
#  'unpaved',
#  'unpeeled',
#  'unripe',
#  'up',
#  'upholstered',
#  'upper',
#  'upside down',
#  'used',
#  'vacant',
#  'vast',
#  'vintage',
#  'vinyl',
#  'warm',
#  'waving',
#  'weathered',
#  'wet',
#  'wii',
#  'wild',
#  'winter',
#  'wired',
#  'wireless',
#  'wispy',
#  'wooded',
#  'worn',
#  'woven',
#  'wrapped',
#  'wrinkled',
#  'wrinkly',
#  'written'}

# %% [markdown]
# Let's compare concept values for the attribute ``rel`` and relation values we extracted before

# %%
pprint(', '.join(attribute_values['rel'].difference(relate_concepts)))
print()
pprint(', '.join(relate_concepts.difference(attribute_values['rel'])))

attribute_values['rel'].update(relate_concepts)
# Out:
# 'looking'
#
# ('walking across, smaller than, on the front of, on the side of, parked along, '
#  'splashing, eating in, grazing in, beside, same color, in between, standing '
#  'around, walking into, sewn on, down, growing near, wading in, traveling '
#  'down, at, on the other side of, parked alongside, skiing down, placed on, '
#  'next to, coming down, growing from, displayed in, playing at, sticking out '
#  'of, walking through, beyond, longer than, larger than, walking up, higher '
#  'than, of, on the bottom of, across, with, in the center of, on the back of, '
#  'near, growing next to, close to, driving down, outside, chained to, along, '
#  'same shape, at the edge of, growing in, growing along, in the middle of, '
#  'same material, by, blowing out, looking toward, drawn on, sitting around, '
#  'over, looking for, pointing to')

# %% [markdown]
# They're pretty much the same, a few concept values that exist when using the ``relate`` primitive dont exist when relation is treated as an attribute concept for ``filter, verify`` etc. We included everything in the vocabulary.
#
# But some attributes dont have values. Let's check them out:

# %%
no_value_attributes = [att for att, v in attribute_values.items() if v == {''}]
pprint(no_value_attributes)
# Out:
# ['healthier',
#  'younger',
#  'smaller',
#  'shorter',
#  'less',
#  'older',
#  'larger',
#  'lower',
#  'taller']

# %% [markdown]
# They are all *superlatives*!! meaning they compare a certain entity with other entities of same semantic category. E.g *''larger bowl''* -> *''bowl larger than other bowls''*. We'll probably need to treat relations with these arguments as separate primitives (e.g. ``relateSuper``).

# %% [markdown]
# # Exploring GQA scene graphs

# %%
scenes = json.load(open(train_scenes_path))
print(f"Total scenes: {len(scenes)}")
print(f'Some image ids: {",".join(list(scenes.keys())[:10])}')
# Out:
# Total scenes: 74942
# Some image ids: 2386621,2373554,2370799,2370791,2370790,2332650,2373556,2414608,2373557,2413658

# %% [markdown]
# Let's inspect a scene graph, and all questions about it

# %%
image_id = '2370799'

# scene location and objects,attributes and relations of scene graph
objects = scenes[image_id]['objects']
if 'location' in scenes.keys():
    print(f"I see {scenes['location']}")
print()
for oid, obj in objects.items():
    print(f"I see {','.join(obj['attributes'])} {obj['name']} ({oid}), {', '.join([r['name'] + ' ' + objects[r['object']]['name'] for r in obj['relations']])}")
    print()

print('==' * 48)

# all questions about that scene
for qid, sample in ds.items():
    if sample['imageId'] == image_id:
        print_qa(sample)
# Out:
# I see  brush (2588934), to the right of mud, to the right of water, to the left of branch
#
# I see  water (2071415), to the left of grass, to the left of brush
#
# I see  branch (1884387), to the right of brush
#
# I see  men (2375807), to the left of bike, to the right of bag, to the left of helmet, to the left of man, riding bike
#
# I see  man (3856641), to the right of men, wearing helmet, to the right of bike, riding bike, to the right of bag
#
# I see  mud (2305851), to the left of grass, to the left of brush
#
# I see  dirt (2198303), to the left of bike, to the left of tires
#
# I see  boot (2205964),
#
# I see  helmet (1974896), to the right of men
#
# I see blue bike (3856635), to the right of dirt, to the left of bike, to the left of man
#
# I see  tires (3856636), to the right of dirt
#
# I see orange bike (1828300), to the right of bike, to the right of men
#
# I see black bag (2129762), to the left of men, to the left of man
#
# I see old tree (2198302),
#
# I see blue helmet (2504852),
#
# I see tall grass (1829233), to the right of mud, to the right of water
#
# ================================================================================================
# Q: Are the men to the left of the helmet riding a skateboard?
# P: select: helmet (1974896)->relate: men,to the left of,s (2375807) [0]->verify rel: skateboard,riding,o (-) [1]
# A: no
#
# Q: The men that are to the left of the helmet are riding what?
# P: select: helmet (1974896)->relate: men,to the left of,s (2375807) [0]->relate: _,riding,o (3856635) [1]->query: name [2]
# A: bike
#
# Q: Who is riding a bike?
# P: select: bike (3856635)->relate: person,riding,s (2375807) [0]->query: name [1]
# A: men
#
# Q: Is the black bag to the right or to the left of the man that wears a helmet?
# P: select: helmet (1974896)->relate: man,wearing,s (3856641) [0]->choose rel: bag,to the left of|to the right of,s (2129762) [1]
# A: left
#
# Q: What color is the helmet in the top?
# P: select: helmet (2504852)->filter vposition: top [0]->query: color [1]
# A: blue
#
# Q: What color is the bike the man is riding?
# P: select: man (3856641)->relate: bike,riding,o (1828300) [0]->query: color [1]
# A: orange
#
# Q: Do you see any grass that is short?
# P: select: grass (1829233)->filter: short [0]->exist: ? [1]
# A: no
#
# Q: Is there either any snow or elephant in the scene?
# P: select: snow (-)->exist: ? [0]->select: elephant (-) ->exist: ? [2]->or:  [1, 3]
# A: no
#
# Q: On which side is the bag?
# P: select: bag (2129762)->query: hposition [0]
# A: left
#
# Q: Who is wearing a helmet?
# P: select: helmet (1974896)->relate: person,wearing,s (3856641) [0]->query: name [1]
# A: man
#
# Q: Are there any paintings or helmets in the photo?
# P: select: helmet (2504852)->exist: ? [0]->select: painting (-) ->exist: ? [2]->or:  [1, 3]
# A: yes
#
# Q: Are there benches or strollers in the image?
# P: select: benches (-)->exist: ? [0]->select: stroller (-) ->exist: ? [2]->or:  [1, 3]
# A: no

# %% [markdown]
# As we see, all questions can be answered by the attributes and relations listed in the scene graph

# %% [markdown]
# # Executing GQA Programs
